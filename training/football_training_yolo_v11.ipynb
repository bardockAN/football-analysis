# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RNkaT5x8e2N5Ww6L6wDM")
project = rf.workspace("ranjit-raut-do9me").project("futvar-football-players-detection-dataset")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'C:\\Users\\tiend\\Downloads\\AI-LABs\\football_analysis\\training\\FutVAR-Football-Players-Detection-Dataset-10'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov11n.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 device='0' batch=4 workers=0
# Out:
# ^C
